# %%
import pandas as pd
import numpy as np
import jax

import os
os.chdir("/home/evelyn/projects_shared/jaxlogit")

from jaxlogit.mixed_logit import ConfigData
from jaxlogit.nested_logit import NestedLogit

os.chdir("/home/evelyn/projects_shared/jaxlogit/examples")

#  64bit precision
jax.config.update("jax_enable_x64", True)

# %%
df_wide = pd.read_table("http://transp-or.epfl.ch/data/swissmetro.dat", sep='\t')

# Keep only observations for commute and business purposes that contain known choices
df_wide = df_wide[(df_wide['PURPOSE'].isin([1, 3]) & (df_wide['CHOICE'] != 0))]

df_wide['custom_id'] = np.arange(len(df_wide))  # Add unique identifier
df_wide['CHOICE'] = df_wide['CHOICE'].map({1: 'TRAIN', 2:'SM', 3: 'CAR'})
df_wide

from jaxlogit.utils import wide_to_long

df = wide_to_long(df_wide, id_col='custom_id', alt_name='alt', sep='_',
                  alt_list=['TRAIN', 'SM', 'CAR'], empty_val=0,
                  varying=['TT', 'CO', 'HE', 'AV', 'SEATS'], alt_is_prefix=True)
df

df['ASC_TRAIN'] = np.ones(len(df))*(df['alt'] == 'TRAIN')
df['ASC_CAR'] = np.ones(len(df))*(df['alt'] == 'CAR')
df['TT'], df['CO'] = df['TT']/100, df['CO']/100  # Scale variables
annual_pass = (df['GA'] == 1) & (df['alt'].isin(['TRAIN', 'SM']))
df.loc[annual_pass, 'CO'] = 0  # Cost zero for pass holders

# %%
nests = {'public transport': ['TRAIN', 'SM']}

# %%
varnames=['ASC_CAR', 'ASC_TRAIN', 'CO', 'TT']
model = NestedLogit()

config = ConfigData(
    avail=(df['AV']),
    panels=(df["ID"]),
)

res = model.fit(
    df[varnames],
    df['CHOICE'],
    varnames,
    df['alt'],
    df['custom_id'],
    {'TT': 'n'},
    nests,
    config,
)
model.summary()
# Out:
# WARNING:2026-01-30 10:42:00,394:jax._src.xla_bridge:854: An NVIDIA GPU may be present on this machine, but a CUDA-enabled jaxlib is not installed. Falling back to cpu.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 9
#       2 model = NestedLogit()
#       4 config = ConfigData(
#       5     avail=(df['AV']),
#       6     panels=(df["ID"]),
#       7 )
# ----> 9 res = model.fit(
#      10     df[varnames],
#      11     df['CHOICE'],
#      12     varnames,
#      13     df['alt'],
#      14     df['custom_id'],
#      15     {'TT': 'n'},
#      16     nests,
#      17     config,
#      18 )
#      19 model.summary()
#
# File ~/projects_shared/jaxlogit/jaxlogit/nested_logit.py:359, in NestedLogit.fit(self, X, y, varnames, alts, ids, randvars, nests, config, verbose)
#     355     tol.update(config.tol_opts)
#     357 fct_to_optimize = neg_loglike_nest
# --> 359 optim_res = _minimize(
#     360     fct_to_optimize,
#     361     betas,
#     362     args=fargs,
#     363     method=config.optim_method,
#     364     tol=tol["ftol"],
#     365     options={
#     366         "gtol": tol["gtol"],
#     367         "maxiter": config.maxiter,
#     368     },
#     369     jit_loglik=config.batch_size is None,
#     370 )
#     371 if optim_res is None:
#     372     _logger.error("Optimization failed, returning None.")
#
# File ~/projects_shared/jaxlogit/jaxlogit/_optimize.py:32, in _minimize(loglik_fn, x, args, method, tol, options, jit_loglik)
#      29     return neg_loglik_and_grad(x, *args)
#      31 if method == "L-BFGS-B":
# ---> 32     return minimize(
#      33         neg_loglike_scipy,
#      34         x,
#      35         args=args,
#      36         jac=True,
#      37         method="L-BFGS-B",
#      38         tol=tol,
#      39         options=options,
#      40     )
#      41 elif method == "BFGS":
#      42     return minimize(
#      43         neg_loglike_scipy,
#      44         x,
#    (...)     48         options=options,
#      49     )
#
# File ~/projects_shared/jaxlogit/venv/lib/python3.12/site-packages/scipy/optimize/_minimize.py:784, in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     781     res = _minimize_newtoncg(fun, x0, args, jac, hess, hessp, callback,
#     782                              **options)
#     783 elif meth == 'l-bfgs-b':
# --> 784     res = _minimize_lbfgsb(fun, x0, args, jac, bounds,
#     785                            callback=callback, **options)
#     786 elif meth == 'tnc':
#     787     res = _minimize_tnc(fun, x0, args, jac, bounds, callback=callback,
#     788                         **options)
#
# File ~/projects_shared/jaxlogit/venv/lib/python3.12/site-packages/scipy/optimize/_lbfgsb_py.py:413, in _minimize_lbfgsb(fun, x0, args, jac, bounds, disp, maxcor, ftol, gtol, eps, maxfun, maxiter, iprint, callback, maxls, finite_diff_rel_step, workers, **unknown_options)
#     410     x0 = np.clip(x0, bounds[0], bounds[1])
#     412 # _prepare_scalar_function can use bounds=None to represent no bounds
# --> 413 sf = _prepare_scalar_function(fun, x0, jac=jac, args=args, epsilon=eps,
#     414                               bounds=bounds,
#     415                               finite_diff_rel_step=finite_diff_rel_step,
#     416                               workers=workers)
#     418 func_and_grad = sf.fun_and_grad
#     420 nbd = zeros(n, np.int32)
#
# File ~/projects_shared/jaxlogit/venv/lib/python3.12/site-packages/scipy/optimize/_optimize.py:310, in _prepare_scalar_function(fun, x0, jac, args, bounds, epsilon, finite_diff_rel_step, hess, workers)
#     306 workers = workers or map
#     308 # ScalarFunction caches. Reuse of fun(x) during grad
#     309 # calculation reduces overall function evaluations.
# --> 310 sf = ScalarFunction(fun, x0, args, grad, hess,
#     311                     finite_diff_rel_step, bounds, epsilon=epsilon,
#     312                     workers=workers)
#     314 return sf
#
# File ~/projects_shared/jaxlogit/venv/lib/python3.12/site-packages/scipy/optimize/_differentiable_functions.py:274, in ScalarFunction.__init__(self, fun, x0, args, grad, hess, finite_diff_rel_step, finite_diff_bounds, epsilon, workers)
#     272 # Initial function evaluation
#     273 self._nfev = 0
# --> 274 self._update_fun()
#     276 # Initial gradient evaluation
#     277 self._wrapped_grad = _ScalarGradWrapper(
#     278     grad,
#     279     fun=self._wrapped_fun,
#     280     args=args,
#     281     finite_diff_options=finite_diff_options,
#     282 )
#
# File ~/projects_shared/jaxlogit/venv/lib/python3.12/site-packages/scipy/optimize/_differentiable_functions.py:353, in ScalarFunction._update_fun(self)
#     351 def _update_fun(self):
#     352     if not self.f_updated:
# --> 353         fx = self._wrapped_fun(self.x)
#     354         self._nfev += 1
#     355         if fx < self._lowest_f:
#
# File ~/projects_shared/jaxlogit/venv/lib/python3.12/site-packages/scipy/_lib/_util.py:590, in _ScalarFunctionWrapper.__call__(self, x)
#     587 def __call__(self, x):
#     588     # Send a copy because the user may overwrite it.
#     589     # The user of this class might want `x` to remain unchanged.
# --> 590     fx = self.f(np.copy(x), *self.args)
#     591     self.nfev += 1
#     593     # Make sure the function returns a true scalar
#
# File ~/projects_shared/jaxlogit/venv/lib/python3.12/site-packages/scipy/optimize/_optimize.py:80, in MemoizeJac.__call__(self, x, *args)
#      78 def __call__(self, x, *args):
#      79     """ returns the function value """
# ---> 80     self._compute_if_needed(x, *args)
#      81     return self._value
#
# File ~/projects_shared/jaxlogit/venv/lib/python3.12/site-packages/scipy/optimize/_optimize.py:74, in MemoizeJac._compute_if_needed(self, x, *args)
#      72 if not np.all(x == self.x) or self._value is None or self.jac is None:
#      73     self.x = np.asarray(x).copy()
# ---> 74     fg = self.fun(x, *args)
#      75     self.jac = fg[1]
#      76     self._value = fg[0]
#
# File ~/projects_shared/jaxlogit/jaxlogit/_optimize.py:29, in _minimize.<locals>.neg_loglike_scipy(betas, *args)
#      27 """Wrapper for neg_loglike to use with scipy."""
#      28 x = jnp.array(betas)
# ---> 29 return neg_loglik_and_grad(x, *args)
#
#     [... skipping hidden 5 frame]
#
# File ~/projects_shared/jaxlogit/venv/lib/python3.12/site-packages/jax/_src/pjit.py:678, in _infer_input_type(fun, dbg_fn, explicit_args)
#     676   dbg = dbg_fn()
#     677   arg_description = f"path {dbg.arg_names[i] if dbg.arg_names is not None else 'unknown'}"  # pytype: disable=name-error
# --> 678   raise TypeError(
#     679     f"Error interpreting argument to {fun} as an abstract array."
#     680     f" The problematic value is of type {type(x)} and was passed to"  # pytype: disable=name-error
#     681     f" the function at {arg_description}.\n"
#     682     "This typically means that a jit-wrapped function was called with a non-array"
#     683     " argument, and this argument was not marked as static using the"
#     684     " static_argnums or static_argnames parameters of jax.jit."
#     685   ) from None
#     686 if config.mutable_array_checks.value:
#     687   check_no_aliased_ref_args(dbg_fn, avals, explicit_args)
#
# TypeError: Error interpreting argument to <function neg_loglike_nest at 0x74b8782cb600> as an abstract array. The problematic value is of type <class 'jaxlogit._variables.ParametersSetup'> and was passed to the function at path args[8].
# This typically means that a jit-wrapped function was called with a non-array argument, and this argument was not marked as static using the static_argnums or static_argnames parameters of jax.jit.
